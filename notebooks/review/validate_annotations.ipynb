# %% [markdown]
# # **Validate Annotations ✅**
#
# This notebook allows to validate the annotations in a JSON file. It checks for overlapping entities and ensures that the entity spans are correctly ordered. The validated annotations are then saved back to the original JSON file.

# %%
# %load_ext autoreload
# %autoreload 2

from mdner_llm.utils.validate_annotations import validate_all_annotations_from_dir
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
validate_all_annotations_from_dir("../../annotations/v3")
# Out:
# 2026-03-24 14:25:10 | INFO     | Validating all annotations in directory: ../../annotations/v3
# 2026-03-24 14:25:10 | INFO     | Found 362 JSON files to validate.
# 2026-03-24 14:25:10 | WARNING  | Span length mismatch: 'DPPC' [804, 809] len(text)=4(../../annotations/v3/zenodo_3950029.json)
# 2026-03-24 14:25:10 | WARNING  | Span length mismatch: 'Charmm36 (v. June 2015)' [1004, 1028] len(text)=23(../../annotations/v3/zenodo_3950029.json)
# 2026-03-24 14:25:10 | WARNING  | Span length mismatch: 'TIP3P' [1037, 1043] len(text)=5(../../annotations/v3/zenodo_3950029.json)
# 2026-03-24 14:25:10 | WARNING  | Overlapping entities: 'ansamer amanitin' [24,40] and 'amanitin' [32,40](../../annotations/v3/zenodo_6974777.json)
# 2026-03-24 14:25:10 | WARNING  | Overlapping entities: 'a-amanitin' [98,108] and 'amanitin' [100,108](../../annotations/v3/zenodo_6974777.json)
# ...
