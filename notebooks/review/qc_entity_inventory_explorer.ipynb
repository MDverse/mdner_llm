# %% [markdown]
# # **QC Entity Inventory Explorer 🔎**
#
# This notebook allows exploration of QC entity inventory results generated
# by `src/mdner_llm/utils/build_entity_vocab.py`.
#
# We can inspect:
#
# - The top entities per class
# - Rare entities with low occurrences
#
# The insights gained here will help define **rules for annotation**,
# to be documented in [`docs/annotation_rules.md`](../docs/annotation_rules.md).
# For example, these rules may include:
#
# - Standardizing numeric formats, such as temperatures in Kelvin (`300 K` → `300K`)
# - Removing unnecessary spaces between values and units
# - Normalizing synonyms or alternative spellings of entity names
#   ...

# %% [markdown]
# ## Load libraries and setup

# %%
from pathlib import Path

from mdner_llm.utils.build_entity_vocab import process_qc_entity_inventory

# %%
# %load_ext watermark
# %watermark
# Out:
# Last updated: 2026-03-02T17:23:26.974018+01:00
#
# Python implementation: CPython
# Python version       : 3.13.0
# IPython version      : 8.13.2
#
# Compiler    : Clang 18.1.8
# OS          : Linux
# Release     : 6.17.0-14-generic
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 32
# Architecture: 64bit

# %% [markdown]
# ## Load data

# %%
# Define the annotation directory
annotation_dir = Path("../../annotations/v3")
# Define the results directory
results_dir = Path("../../results/qc_annotations")

# %%
# Process the QC entity inventory
# Get dictionnary containing entity counts for each class label
entity_data = process_qc_entity_inventory(annotation_dir, results_dir)
# Out:
# 2026-03-02 17:23:26 | INFO     | Starting QC entity inventory.
# 2026-03-02 17:23:26 | INFO     | Collecting entity counts.
# 2026-03-02 17:23:26 | SUCCESS  | Found 360 JSON annotation files.
# 2026-03-02 17:23:27 | SUCCESS  | Collected entity counts for 6 classes: FFM, MOL, SOFTNAME, SOFTVERS, STIME, TEMP!
# 2026-03-02 17:23:27 | INFO     | Saving QC inventory files to ../../results/qc_annotations.
# 2026-03-02 17:23:27 | SUCCESS  | QC entity inventory completed successfully!

# %%
print("Annotation summary by class:")
print("-" * 50)
print(f"{'Class':20} | {'Total occurrences':17} | {'Unique entities':15}")
print("-" * 50)

# Trier par total_occurrences décroissant
for class_name, df in sorted(
    entity_data.items(), key=lambda x: x[1]["count"].sum(), reverse=True
):
    total_occurrences = df["count"].sum()
    unique_entities = df.shape[0]
    print(f"{class_name:20} | {total_occurrences:17} | {unique_entities:15}")

print("-" * 50)
# Out:
# Annotation summary by class:
# --------------------------------------------------
# Class                | Total occurrences | Unique entities
# --------------------------------------------------
# MOL                  |              3223 |            1060
# FFM                  |               380 |              94
# SOFTNAME             |               331 |              78
# STIME                |               166 |              86
# TEMP                 |               125 |              50
# SOFTVERS             |                80 |              49
# --------------------------------------------------

# %% [markdown]
# ##

# %% [markdown]
# ## Molecules 🧬

# %%
df = entity_data["MOL"].sort_values("count", ascending=False)
df
# Out:
#                              entity  count  \
# 0                             water    197
# 1                              popc    100
# 2                              dppc     53
# 3                       cholesterol     53
# 4                              nacl     44
# ...                             ...    ...
# 1055  di-, tri- and tetra-ubiquitin      1
# 1056                            mif      1
# 1057                           2rjy      1
# 1058                          bcl-2      1
# 1059                dimethoxyethane      1
#
#                                        annotation_paths
# 0     ../../annotations/v3/figshare_11569377.json,.....
# 1     ../../annotations/v3/figshare_10287393.json,.....
# 2     ../../annotations/v3/figshare_2018634.json,../...
# 3     ../../annotations/v3/figshare_10287393.json,.....
# 4     ../../annotations/v3/figshare_20485017.json,.....
# ...                                                 ...
# 1055           ../../annotations/v3/zenodo_3878218.json
# 1056         ../../annotations/v3/figshare_9941741.json
# 1057         ../../annotations/v3/figshare_3983526.json
# 1058           ../../annotations/v3/zenodo_4012224.json
# 1059        ../../annotations/v3/figshare_22203473.json
#
# [1060 rows x 3 columns]

# %%
total_entities = len(df)
rare_df = df[df["count"] == 1]
num_rare = len(rare_df)

print(f"Rare molecules (count = 1): {num_rare} / {total_entities} total entities")
rare_df
# Out:
# Rare molecules (count = 1): 525 / 1060 total entities
#                              entity  count  \
# 535                      lipid acyl      1
# 536                         histone      1
# 537                     chromosomes      1
# 538                            ncps      1
# 539                           amide      1
# ...                             ...    ...
# 1055  di-, tri- and tetra-ubiquitin      1
# 1056                            mif      1
# 1057                           2rjy      1
# 1058                          bcl-2      1
# 1059                dimethoxyethane      1
#
#                                  annotation_paths
# 535      ../../annotations/v3/zenodo_4445375.json
# 536   ../../annotations/v3/figshare_19780550.json
# 537   ../../annotations/v3/figshare_19780550.json
# 538   ../../annotations/v3/figshare_19780550.json
# 539      ../../annotations/v3/zenodo_6503359.json
# ...                                           ...
# 1055     ../../annotations/v3/zenodo_3878218.json
# 1056   ../../annotations/v3/figshare_9941741.json
# 1057   ../../annotations/v3/figshare_3983526.json
# 1058     ../../annotations/v3/zenodo_4012224.json
# 1059  ../../annotations/v3/figshare_22203473.json
#
# [525 rows x 3 columns]

# %% [markdown]
# ## Force Field Model Name 🛠️

# %%
df = entity_data["FFM"].sort_values("count", ascending=False)
df
# Out:
#       entity  count                                   annotation_paths
# 0   charmm36     44  ../../annotations/v3/figshare_14225919.json,.....
# 1    martini     34  ../../annotations/v3/figshare_11569377.json,.....
# 2     charmm     27  ../../annotations/v3/figshare_14498668.json,.....
# 3      amber     25  ../../annotations/v3/figshare_11688372.json,.....
# 4      tip3p     23  ../../annotations/v3/figshare_13135976.json,.....
# ..       ...    ...                                                ...
# 89       gap      1           ../../annotations/v3/zenodo_7112198.json
# 90    bind3p      1        ../../annotations/v3/figshare_11808522.json
# 91      gdml      1           ../../annotations/v3/zenodo_7112198.json
# 92    schnet      1           ../../annotations/v3/zenodo_7112198.json
# 93    l-opls      1        ../../annotations/v3/figshare_14225919.json
#
# [94 rows x 3 columns]

# %%
total_entities = len(df)
rare_df = df[df["count"] == 1]
num_rare = len(rare_df)

print(
    f"Rare force field or model (count = 1): {num_rare} / {total_entities} total entities"
)
rare_df
# Out:
# Rare force field or model (count = 1): 42 / 94 total entities
#                                      entity  count  \
# 52                                  lipid14      1
# 53                                charmm 27      1
# 54                               gromos54a7      1
# 55                              gromos 53a6      1
# 56                                  amber14      1
# 57                                   amoeba      1
# 58                                  'berger      1
# 59                                    ff03w      1
# 60                                     ff03      1
# 61                                    ff03*      1
# 62                                  lipid17      1
# 63                                opls-aa/m      1
# 64                                    c36m.      1
# 65                              martini 3.0      1
# 66                                  ff99sb*      1
# 67                              ff99sb-ildn      1
# 68                                   parm99      1
# 69                                 parmbsc0      1
# 70                               tip4p/2005      1
# 71                                trappe-ua      1
# 72                                amber14sb      1
# 73                                     ff96      1
# 74                                     ff99      1
# 75                                    rsff1      1
# 76            generalized amber force field      1
# 77                                      tip      1
# 78                                  q4md-cd      1
# 79                               charmm36mw      1
# 80                               charmm36m.      1
# 81                                martini 3      1
# 82                             martini 2.2p      1
# 83                               martini cg      1
# 84                        amber ff99sb-ildn      1
# 85                             amber ff99sb      1
# 86                                 autodock      1
# 87  charmm36 forcefield (version july 2020)      1
# 88                                 tip4p-ew      1
# 89                                      gap      1
# 90                                   bind3p      1
# 91                                     gdml      1
# 92                                   schnet      1
# 93                                   l-opls      1
#
#                                annotation_paths
# 52       ../../annotations/v3/zenodo_34415.json
# 53   ../../annotations/v3/figshare_3983526.json
# 54   ../../annotations/v3/figshare_4806544.json
# 55  ../../annotations/v3/figshare_11771604.json
# 56     ../../annotations/v3/zenodo_4805388.json
# 57   ../../annotations/v3/figshare_8258741.json
# 58       ../../annotations/v3/zenodo_51748.json
# 59   ../../annotations/v3/figshare_2532337.json
# 60   ../../annotations/v3/figshare_2532337.json
# 61   ../../annotations/v3/figshare_2532337.json
# 62     ../../annotations/v3/zenodo_3610470.json
# 63   ../../annotations/v3/figshare_9941741.json
# 64   ../../annotations/v3/figshare_9788852.json
# 65     ../../annotations/v3/zenodo_6010416.json
# 66   ../../annotations/v3/figshare_2532337.json
# 67   ../../annotations/v3/figshare_2532337.json
# 68  ../../annotations/v3/figshare_19102457.json
# 69  ../../annotations/v3/figshare_19102457.json
# 70  ../../annotations/v3/figshare_13836577.json
# 71  ../../annotations/v3/figshare_13836577.json
# 72     ../../annotations/v3/zenodo_3975394.json
# 73   ../../annotations/v3/figshare_2532337.json
# 74   ../../annotations/v3/figshare_2532337.json
# 75   ../../annotations/v3/figshare_3207154.json
# 76   ../../annotations/v3/figshare_5106286.json
# 77  ../../annotations/v3/figshare_12064266.json
# 78  ../../annotations/v3/figshare_11808522.json
# 79     ../../annotations/v3/zenodo_5573728.json
# 80     ../../annotations/v3/zenodo_6592231.json
# 81     ../../annotations/v3/zenodo_5060102.json
# 82     ../../annotations/v3/zenodo_6973476.json
# 83   ../../annotations/v3/figshare_2154835.json
# 84     ../../annotations/v3/zenodo_6349893.json
# 85     ../../annotations/v3/zenodo_6349893.json
# 86    ../../annotations/v3/figshare_121241.json
# 87     ../../annotations/v3/zenodo_7037843.json
# 88  ../../annotations/v3/figshare_12987701.json
# 89     ../../annotations/v3/zenodo_7112198.json
# 90  ../../annotations/v3/figshare_11808522.json
# 91     ../../annotations/v3/zenodo_7112198.json
# 92     ../../annotations/v3/zenodo_7112198.json
# 93  ../../annotations/v3/figshare_14225919.json

# %% [markdown]
# ## Software name ⚙️

# %%
df = entity_data["SOFTNAME"].sort_values("count", ascending=False)
df
# Out:
#         entity  count                                   annotation_paths
# 0      gromacs    134  ../../annotations/v3/figshare_13116890.json,.....
# 1       lammps     18  ../../annotations/v3/figshare_16772812.json,.....
# 2        amber     16  ../../annotations/v3/figshare_12987701.json,.....
# 3          vmd     15  ../../annotations/v3/figshare_13352375.json,.....
# 4   charmm-gui      8  ../../annotations/v3/zenodo_1198158.json,../.....
# ..         ...    ...                                                ...
# 73    chimerax      1           ../../annotations/v3/zenodo_7007107.json
# 74     flexaid      1           ../../annotations/v3/zenodo_2586559.json
# 75       rdock      1           ../../annotations/v3/zenodo_2586559.json
# 76       gibbs      1         ../../annotations/v3/figshare_2267512.json
# 77  hoomd-blue      1           ../../annotations/v3/zenodo_6957888.json
#
# [78 rows x 3 columns]

# %%
total_entities = len(df)
rare_df = df[df["count"] == 1]
num_rare = len(rare_df)

print(f"Rare software names (count = 1): {num_rare} / {total_entities} total entities")
rare_df
# Out:
# Rare software names (count = 1): 43 / 78 total entities
#             entity  count                             annotation_paths
# 35           acemd      1   ../../annotations/v3/figshare_3983526.json
# 36        gaussian      1     ../../annotations/v3/zenodo_7273800.json
# 37       swissprot      1     ../../annotations/v3/zenodo_4730896.json
# 38       paramchem      1     ../../annotations/v3/zenodo_6988344.json
# 39           namd2      1     ../../annotations/v3/zenodo_4245236.json
# 40      gaussian16      1     ../../annotations/v3/zenodo_3361945.json
# 41             moe      1     ../../annotations/v3/zenodo_4245236.json
# 42       lipidbook      1       ../../annotations/v3/zenodo_13392.json
# 43           optim      1     ../../annotations/v3/zenodo_7107608.json
# 44        gromacs,      1   ../../annotations/v3/figshare_5532214.json
# 45           prody      1   ../../annotations/v3/figshare_4806544.json
# 46          github      1     ../../annotations/v3/zenodo_3610470.json
# 47       doglycans      1   ../../annotations/v3/figshare_5496910.json
# 48       alphafold      1     ../../annotations/v3/zenodo_5642866.json
# 49      glycam-web      1  ../../annotations/v3/figshare_12272015.json
# 50      pathsample      1     ../../annotations/v3/zenodo_7107608.json
# 51          glycam      1     ../../annotations/v3/zenodo_5592299.json
# 52        intermol      1     ../../annotations/v3/zenodo_5592299.json
# 53          visual      1     ../../annotations/v3/zenodo_6879091.json
# 54          molsim      1     ../../annotations/v3/zenodo_7523635.json
# 55  gromacs-2020.6      1     ../../annotations/v3/zenodo_6349893.json
# 56           glide      1     ../../annotations/v3/zenodo_3567651.json
# 57           pymol      1     ../../annotations/v3/zenodo_6349893.json
# 58            aimd      1     ../../annotations/v3/zenodo_7234728.json
# 59         rosetta      1  ../../annotations/v3/figshare_19082291.json
# 60      deepmd-kit      1     ../../annotations/v3/zenodo_7234728.json
# 61          molpro      1     ../../annotations/v3/zenodo_6791151.json
# 62        unitymol      1     ../../annotations/v3/zenodo_5060102.json
# 63          asegui      1     ../../annotations/v3/zenodo_5060102.json
# 64             ase      1     ../../annotations/v3/zenodo_5060102.json
# 65        torchani      1     ../../annotations/v3/zenodo_5060102.json
# 66          colvar      1     ../../annotations/v3/zenodo_7323535.json
# 67          prmtop      1     ../../annotations/v3/zenodo_6870476.json
# 68       autodock4      1     ../../annotations/v3/zenodo_6592231.json
# 69         maestro      1     ../../annotations/v3/zenodo_3362889.json
# 70      pyinteraph      1     ../../annotations/v3/zenodo_1346073.json
# 71           pmemd      1   ../../annotations/v3/figshare_4757161.json
# 72        autodock      1     ../../annotations/v3/zenodo_2586559.json
# 73        chimerax      1     ../../annotations/v3/zenodo_7007107.json
# 74         flexaid      1     ../../annotations/v3/zenodo_2586559.json
# 75           rdock      1     ../../annotations/v3/zenodo_2586559.json
# 76           gibbs      1   ../../annotations/v3/figshare_2267512.json
# 77      hoomd-blue      1     ../../annotations/v3/zenodo_6957888.json

# %% [markdown]
# ## Software version 🔢

# %%
df = entity_data["SOFTVERS"].sort_values("count", ascending=False)
df
# Out:
#                               entity  count  \
# 0                                3.x      7
# 1                              4.0.7      7
# 2                                4.5      6
# 3                              5.1.4      4
# 4                               2020      3
# 5                              5.0.3      3
# 6                                 19      2
# 7                               4.5.      2
# 8                             2018.3      2
# 9                                  7      2
# 10                                16      2
# 11                             5.1.1      2
# 12                       (v. 2016.4)      2
# 13                            5.0.3.      1
# 14                        16 rev b01      1
# 15                (dec 2018, stable)      1
# 16                  stable dec. 2018      1
# 17                             3.3.3      1
# 18                              2019      1
# 19                       version 4.6      1
# 20                             5.0.x      1
# 21       2016.2-dev-20170105-4feb0be      1
# 22                            2016.3      1
# 23                             1.9.3      1
# 24                               2.0      1
# 25                              2018      1
# 26                molecular dynamics      1
# 27  simulation engine version 2019.4      1
# 28                            2018.0      1
# 29                             tools      1
# 30                         (v. 2020)      1
# 31                             5.0.6      1
# 32                     version 2.6.0      1
# 33                             5.1.x      1
# 34              simulation engine v5      1
# 35                           v.4.6.5      1
# 36                            2021.4      1
# 37                             v9.16      1
# 38                            (v4.6)      1
# 39                            2016.1      1
# 40                             5.1.5      1
# 41                             4.6.5      1
# 42                             4.5.6      1
# 43                              v2.4      1
# 44                              2021      1
# 45                            2020.4      1
# 46                             4.6->      1
# 47                              vina      1
# 48              software (v. 2016.4)      1
#
#                                      annotation_paths
# 0   ../../annotations/v3/zenodo_51747.json,../../a...
# 1   ../../annotations/v3/zenodo_1293762.json,../.....
# 2   ../../annotations/v3/zenodo_13814.json,../../a...
# 3   ../../annotations/v3/zenodo_1118682.json,../.....
# 4   ../../annotations/v3/figshare_13352375.json,.....
# 5   ../../annotations/v3/zenodo_30894.json,../../a...
# 6            ../../annotations/v3/zenodo_3786821.json
# 7   ../../annotations/v3/zenodo_44622.json,../../a...
# 8   ../../annotations/v3/zenodo_3865919.json,../.....
# 9   ../../annotations/v3/figshare_5247880.json,../...
# 10         ../../annotations/v3/figshare_4757161.json
# 11             ../../annotations/v3/zenodo_55565.json
# 12  ../../annotations/v3/zenodo_3950029.json,../.....
# 13             ../../annotations/v3/zenodo_34415.json
# 14           ../../annotations/v3/zenodo_7273800.json
# 15           ../../annotations/v3/zenodo_7273800.json
# 16           ../../annotations/v3/zenodo_7273800.json
# 17         ../../annotations/v3/figshare_4806544.json
# 18           ../../annotations/v3/zenodo_3592499.json
# 19         ../../annotations/v3/figshare_5532214.json
# 20            ../../annotations/v3/zenodo_838635.json
# 21           ../../annotations/v3/zenodo_1219494.json
# 22           ../../annotations/v3/zenodo_1167532.json
# 23           ../../annotations/v3/zenodo_4730896.json
# 24           ../../annotations/v3/zenodo_3696970.json
# 25           ../../annotations/v3/zenodo_6755131.json
# 26           ../../annotations/v3/zenodo_6879091.json
# 27           ../../annotations/v3/zenodo_3667662.json
# 28           ../../annotations/v3/zenodo_1488094.json
# 29         ../../annotations/v3/figshare_5496910.json
# 30           ../../annotations/v3/zenodo_4300706.json
# 31           ../../annotations/v3/zenodo_1293813.json
# 32           ../../annotations/v3/zenodo_3865919.json
# 33           ../../annotations/v3/zenodo_6817824.json
# 34            ../../annotations/v3/zenodo_247386.json
# 35        ../../annotations/v3/figshare_13135976.json
# 36           ../../annotations/v3/zenodo_7323535.json
# 37        ../../annotations/v3/figshare_13135976.json
# 38            ../../annotations/v3/zenodo_238943.json
# 39           ../../annotations/v3/zenodo_3248612.json
# 40           ../../annotations/v3/zenodo_6973476.json
# 41           ../../annotations/v3/zenodo_3908769.json
# 42           ../../annotations/v3/zenodo_3236015.json
# 43           ../../annotations/v3/zenodo_7533587.json
# 44           ../../annotations/v3/zenodo_7533587.json
# 45           ../../annotations/v3/zenodo_7007107.json
# 46            ../../annotations/v3/zenodo_259443.json
# 47           ../../annotations/v3/zenodo_2586559.json
# 48           ../../annotations/v3/zenodo_3901180.json

# %%
total_entities = len(df)
rare_df = df[df["count"] == 1]
num_rare = len(rare_df)

print(
    f"Rare software versions (count = 1): {num_rare} / {total_entities} total entities"
)
rare_df
# Out:
# Rare software versions (count = 1): 36 / 49 total entities
#                               entity  count  \
# 13                            5.0.3.      1
# 14                        16 rev b01      1
# 15                (dec 2018, stable)      1
# 16                  stable dec. 2018      1
# 17                             3.3.3      1
# 18                              2019      1
# 19                       version 4.6      1
# 20                             5.0.x      1
# 21       2016.2-dev-20170105-4feb0be      1
# 22                            2016.3      1
# 23                             1.9.3      1
# 24                               2.0      1
# 25                              2018      1
# 26                molecular dynamics      1
# 27  simulation engine version 2019.4      1
# 28                            2018.0      1
# 29                             tools      1
# 30                         (v. 2020)      1
# 31                             5.0.6      1
# 32                     version 2.6.0      1
# 33                             5.1.x      1
# 34              simulation engine v5      1
# 35                           v.4.6.5      1
# 36                            2021.4      1
# 37                             v9.16      1
# 38                            (v4.6)      1
# 39                            2016.1      1
# 40                             5.1.5      1
# 41                             4.6.5      1
# 42                             4.5.6      1
# 43                              v2.4      1
# 44                              2021      1
# 45                            2020.4      1
# 46                             4.6->      1
# 47                              vina      1
# 48              software (v. 2016.4)      1
#
#                                annotation_paths
# 13       ../../annotations/v3/zenodo_34415.json
# 14     ../../annotations/v3/zenodo_7273800.json
# 15     ../../annotations/v3/zenodo_7273800.json
# 16     ../../annotations/v3/zenodo_7273800.json
# 17   ../../annotations/v3/figshare_4806544.json
# 18     ../../annotations/v3/zenodo_3592499.json
# 19   ../../annotations/v3/figshare_5532214.json
# 20      ../../annotations/v3/zenodo_838635.json
# 21     ../../annotations/v3/zenodo_1219494.json
# 22     ../../annotations/v3/zenodo_1167532.json
# 23     ../../annotations/v3/zenodo_4730896.json
# 24     ../../annotations/v3/zenodo_3696970.json
# 25     ../../annotations/v3/zenodo_6755131.json
# 26     ../../annotations/v3/zenodo_6879091.json
# 27     ../../annotations/v3/zenodo_3667662.json
# 28     ../../annotations/v3/zenodo_1488094.json
# 29   ../../annotations/v3/figshare_5496910.json
# 30     ../../annotations/v3/zenodo_4300706.json
# 31     ../../annotations/v3/zenodo_1293813.json
# 32     ../../annotations/v3/zenodo_3865919.json
# 33     ../../annotations/v3/zenodo_6817824.json
# 34      ../../annotations/v3/zenodo_247386.json
# 35  ../../annotations/v3/figshare_13135976.json
# 36     ../../annotations/v3/zenodo_7323535.json
# 37  ../../annotations/v3/figshare_13135976.json
# 38      ../../annotations/v3/zenodo_238943.json
# 39     ../../annotations/v3/zenodo_3248612.json
# 40     ../../annotations/v3/zenodo_6973476.json
# 41     ../../annotations/v3/zenodo_3908769.json
# 42     ../../annotations/v3/zenodo_3236015.json
# 43     ../../annotations/v3/zenodo_7533587.json
# 44     ../../annotations/v3/zenodo_7533587.json
# 45     ../../annotations/v3/zenodo_7007107.json
# 46      ../../annotations/v3/zenodo_259443.json
# 47     ../../annotations/v3/zenodo_2586559.json
# 48     ../../annotations/v3/zenodo_3901180.json

# %% [markdown]
# ## Simulation time ⏱

# %%
df = entity_data["STIME"].sort_values("count", ascending=False)
df
# Out:
#          entity  count                                   annotation_paths
# 0         500ns     12  ../../annotations/v3/zenodo_1009027.json,../.....
# 1   microsecond      9  ../../annotations/v3/figshare_20376757.json,.....
# 2        200 ns      9  ../../annotations/v3/figshare_2527738.json,../...
# 3         100ns      9  ../../annotations/v3/zenodo_14591.json,../../a...
# 4        500 ns      8  ../../annotations/v3/zenodo_259443.json,../../...
# ..          ...    ...                                                ...
# 81       800 ns      1            ../../annotations/v3/zenodo_259443.json
# 82          0.6      1         ../../annotations/v3/figshare_5642866.json
# 83       1.6 μs      1         ../../annotations/v3/figshare_5642866.json
# 84       1.6 ns      1        ../../annotations/v3/figshare_20376757.json
# 85       190 ns      1             ../../annotations/v3/zenodo_53212.json
#
# [86 rows x 3 columns]

# %%
total_entities = len(df)
rare_df = df[df["count"] == 1]
num_rare = len(rare_df)

print(
    f"Rare simulation times (count = 1): {num_rare} / {total_entities} total entities"
)
rare_df
# Out:
# Rare simulation times (count = 1): 61 / 86 total entities
#      entity  count                             annotation_paths
# 25     40ns      1       ../../annotations/v3/zenodo_13853.json
# 26  4200 ns      1     ../../annotations/v3/zenodo_3228177.json
# 27    11 ns      1       ../../annotations/v3/zenodo_51750.json
# 28    167ns      1       ../../annotations/v3/zenodo_44660.json
# 29   0.5 μs      1     ../../annotations/v3/zenodo_4106413.json
# ..      ...    ...                                          ...
# 81   800 ns      1      ../../annotations/v3/zenodo_259443.json
# 82      0.6      1   ../../annotations/v3/figshare_5642866.json
# 83   1.6 μs      1   ../../annotations/v3/figshare_5642866.json
# 84   1.6 ns      1  ../../annotations/v3/figshare_20376757.json
# 85   190 ns      1       ../../annotations/v3/zenodo_53212.json
#
# [61 rows x 3 columns]

# %% [markdown]
# ## Temperature 🌡️

# %%
df = entity_data["TEMP"].sort_values("count", ascending=False)
df
# Out:
#       entity  count                                   annotation_paths
# 0       310k     18  ../../annotations/v3/figshare_8046437.json,../...
# 1      310 k     13  ../../annotations/v3/figshare_11764158.json,.....
# 2      300 k     10  ../../annotations/v3/figshare_2615170.json,../...
# 3      298 k      7  ../../annotations/v3/figshare_20485017.json,.....
# 4      323 k      6  ../../annotations/v3/zenodo_51747.json,../../a...
# 5       325k      5  ../../annotations/v3/zenodo_1009027.json,../.....
# 6       288k      4  ../../annotations/v3/zenodo_3950029.json,../.....
# 7       323k      4  ../../annotations/v3/zenodo_14591.json,../../a...
# 8       303k      4  ../../annotations/v3/zenodo_1009607.json,../.....
# 9       358k      4  ../../annotations/v3/zenodo_3950029.json,../.....
# 10     313 k      3  ../../annotations/v3/zenodo_1118682.json,../.....
# 11    298.15      3  ../../annotations/v3/zenodo_30894.json,../../a...
# 12    283.15      2        ../../annotations/v3/figshare_16698491.json
# 13  318.15 k      2        ../../annotations/v3/figshare_16698491.json
# 14      320k      2           ../../annotations/v3/zenodo_1009027.json
# 15      338k      2           ../../annotations/v3/zenodo_1009027.json
# 16     363 k      2           ../../annotations/v3/zenodo_7007107.json
# 17  298.15 k      2           ../../annotations/v3/zenodo_7112198.json
# 18      300k      1        ../../annotations/v3/figshare_16574000.json
# 19        25      1        ../../annotations/v3/figshare_12661589.json
# 20      315k      1           ../../annotations/v3/zenodo_1009027.json
# 21      322k      1           ../../annotations/v3/zenodo_1009027.json
# 22       200      1           ../../annotations/v3/zenodo_4106413.json
# 23     225 k      1           ../../annotations/v3/zenodo_4106413.json
# 24       315      1           ../../annotations/v3/zenodo_1009027.json
# 25     338 k      1           ../../annotations/v3/zenodo_1009027.json
# 26     130 k      1        ../../annotations/v3/figshare_22213635.json
# 27    5000 k      1        ../../annotations/v3/figshare_12218135.json
# 28     333 k      1           ../../annotations/v3/zenodo_2653735.json
# 29       320      1           ../../annotations/v3/zenodo_2653735.json
# 30       298      1           ../../annotations/v3/zenodo_2653735.json
# 31       310      1           ../../annotations/v3/zenodo_2653735.json
# 32      298k      1           ../../annotations/v3/zenodo_1167532.json
# 33       285      1           ../../annotations/v3/zenodo_2653735.json
# 34      3500      1           ../../annotations/v3/zenodo_7234728.json
# 35      3000      1           ../../annotations/v3/zenodo_7234728.json
# 36      2500      1           ../../annotations/v3/zenodo_7234728.json
# 37     295 k      1         ../../annotations/v3/figshare_4541035.json
# 38     340 k      1           ../../annotations/v3/zenodo_6380887.json
# 39  473.15 k      1        ../../annotations/v3/figshare_13836577.json
# 40       303      1            ../../annotations/v3/zenodo_247386.json
# 41    4000 k      1           ../../annotations/v3/zenodo_7234728.json
# 42    293.15      1        ../../annotations/v3/figshare_21726720.json
# 43  313.15 k      1        ../../annotations/v3/figshare_21726720.json
# 44     365 k      1        ../../annotations/v3/figshare_16715821.json
# 45      363k      1           ../../annotations/v3/zenodo_7007107.json
# 46     293 k      1            ../../annotations/v3/zenodo_259443.json
# 47       242      1        ../../annotations/v3/figshare_12987701.json
# 48     210 k      1        ../../annotations/v3/figshare_12987701.json
# 49  273.15 k      1        ../../annotations/v3/figshare_12987701.json

# %%
total_entities = len(df)
rare_df = df[df["count"] == 1]
num_rare = len(rare_df)

print(f"Rare temperatures (count = 1): {num_rare} / {total_entities} total entities")
rare_df
# Out:
# Rare temperatures (count = 1): 32 / 50 total entities
#       entity  count                             annotation_paths
# 18      300k      1  ../../annotations/v3/figshare_16574000.json
# 19        25      1  ../../annotations/v3/figshare_12661589.json
# 20      315k      1     ../../annotations/v3/zenodo_1009027.json
# 21      322k      1     ../../annotations/v3/zenodo_1009027.json
# 22       200      1     ../../annotations/v3/zenodo_4106413.json
# 23     225 k      1     ../../annotations/v3/zenodo_4106413.json
# 24       315      1     ../../annotations/v3/zenodo_1009027.json
# 25     338 k      1     ../../annotations/v3/zenodo_1009027.json
# 26     130 k      1  ../../annotations/v3/figshare_22213635.json
# 27    5000 k      1  ../../annotations/v3/figshare_12218135.json
# 28     333 k      1     ../../annotations/v3/zenodo_2653735.json
# 29       320      1     ../../annotations/v3/zenodo_2653735.json
# 30       298      1     ../../annotations/v3/zenodo_2653735.json
# 31       310      1     ../../annotations/v3/zenodo_2653735.json
# 32      298k      1     ../../annotations/v3/zenodo_1167532.json
# 33       285      1     ../../annotations/v3/zenodo_2653735.json
# 34      3500      1     ../../annotations/v3/zenodo_7234728.json
# 35      3000      1     ../../annotations/v3/zenodo_7234728.json
# 36      2500      1     ../../annotations/v3/zenodo_7234728.json
# 37     295 k      1   ../../annotations/v3/figshare_4541035.json
# 38     340 k      1     ../../annotations/v3/zenodo_6380887.json
# 39  473.15 k      1  ../../annotations/v3/figshare_13836577.json
# 40       303      1      ../../annotations/v3/zenodo_247386.json
# 41    4000 k      1     ../../annotations/v3/zenodo_7234728.json
# 42    293.15      1  ../../annotations/v3/figshare_21726720.json
# 43  313.15 k      1  ../../annotations/v3/figshare_21726720.json
# 44     365 k      1  ../../annotations/v3/figshare_16715821.json
# 45      363k      1     ../../annotations/v3/zenodo_7007107.json
# 46     293 k      1      ../../annotations/v3/zenodo_259443.json
# 47       242      1  ../../annotations/v3/figshare_12987701.json
# 48     210 k      1  ../../annotations/v3/figshare_12987701.json
# 49  273.15 k      1  ../../annotations/v3/figshare_12987701.json
