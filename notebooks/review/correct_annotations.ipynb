# %% [markdown]
# # **Correct annotations 🛠️**

# %% [markdown]
# ## Load libraries

# %%
# %load_ext autoreload
# %autoreload 2

from mdner_llm.utils.correct_annotations import correct_and_visualize

# %%
# %load_ext watermark
# %watermark
# Out:
# Last updated: 2026-04-10T19:00:51.968549+02:00
#
# Python implementation: CPython
# Python version       : 3.13.11
# IPython version      : 8.13.2
#
# Compiler    : GCC 14.3.0
# OS          : Linux
# Release     : 6.17.0-19-generic
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 14
# Architecture: 64bit

# %% [markdown]
# ### Examples
#
# Visualize only:
#
# ```python
# correct_and_visualize(
#     # Path to the annotation file to correct
#     "../../data/annotations/zenodo_838635.json",
#     None,
#     None
# )
# ```
#
# Visualize and correct:
#
# ```python
# correct_and_visualize(
#     # Path to the annotation file to correct
#     "../../data/annotations/zenodo_838635.json",
#     # List of entities to add (entity type, entity text)
#     [("FFM", "Charmm36")],
#     # List of entities to remove (entity type, entity text, occurrence index)
#     # The occurrence index is used to specify which instance of the entity to remove
#     # if there are multiple occurrences. If None, all occurrences will be removed.
#     [("FFM", "Charmm36+OPC", 0), ("MOL", "water", None)],
# )
# ```

# %%
# EXAMPLE
correct_and_visualize(
    # Path to the annotation file to correct
    "../../data/annotations/figshare_5051593.json",
    None,
    None,
)
# Out:
# ================================================================================
# VISUALIZATION OF ENTITIES (figshare_5051593.json: https://figshare.com/articles/dataset/P3HT_and_PCBM_atomistic_force_fields/5051593)
# ================================================================================
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 2
#       1 # EXAMPLE
# ----> 2 correct_and_visualize(
#       3     # Path to the annotation file to correct
#       4     "../../data/annotations/figshare_5051593.json",
#       5     None,
#       6     None,
#       7 )
#
# File ~/workp/projects/2019_MDverse/dev/mdner_llm.git/src/mdner_llm/utils/correct_annotations.py:178, in correct_and_visualize(file_path, add_ent, remove_ent)
#     175 if remove_ent:
#     176     remove_entity_annotation_file(file_path, remove_ent)
# --> 178 visualize_annotations_from_json_file(file_path)
#
# File ~/workp/projects/2019_MDverse/dev/mdner_llm.git/src/mdner_llm/utils/visualize_annotations.py:79, in visualize_annotations_from_json_file(file_path)
#      76 print("=" * 80)
#      78 # Convert annotations and render with displaCy
# ---> 79 converted_data = _convert_annotations_to_displacy(data)
#      80 displacy.render(
#      81     converted_data, style="ent", manual=True, options={"colors": COLORS}
#      82 )
#      84 print()
#
# File ~/workp/projects/2019_MDverse/dev/mdner_llm.git/src/mdner_llm/utils/visualize_annotations.py:50, in _convert_annotations_to_displacy(json_data)
#      27 """
#      28 Convert a custom JSON annotation file to spaCy displaCy format.
#      29
#    (...)
#      43     with keys "text" and "ents".
#      44 """
#      45 # Convert entity spans to displaCy-compatible format
#      46 ents = [
#      47     {
#      48         "start": item["start"],
#      49         "end": item["end"],
# ---> 50         "label": item["category"],
#      51     }
#      52     for item in json_data["entities"]
#      53 ]
#      55 # Return displaCy input structure
#      56 return [{"text": json_data["raw_text"], "ents": ents}]
#
# KeyError: 'category'
