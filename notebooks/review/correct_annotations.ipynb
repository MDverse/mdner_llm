# %% [markdown]
# # **Correct annotations 🛠️**

# %% [markdown]
# ## Load libraries

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path

from mdner_llm.utils.correct_annotations import (
    clean_annotation_file_temperatures,
    correct_and_visualize,
)
from mdner_llm.utils.count_entities import list_json_files
from mdner_llm.utils.select_annotation_files import select_annotation_files

# %%
# %load_ext watermark
# %watermark
# Out:
# Last updated: 2026-03-25T17:19:32.568852+01:00
#
# Python implementation: CPython
# Python version       : 3.13.11
# IPython version      : 8.13.2
#
# Compiler    : GCC 14.3.0
# OS          : Linux
# Release     : 6.17.0-19-generic
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 14
# Architecture: 64bit

# %% [markdown]
# ### Examples
#
# Visualize only:
#
# ```python
# correct_and_visualize(
#     # Path to the annotation file to correct
#     "../../annotations/v3/zenodo_838635.json",
#     None,
#     None
# )
# ```
#
# Visualize and correct:
#
# ```python
# correct_and_visualize(
#     # Path to the annotation file to correct
#     "../../annotations/v3/zenodo_838635.json",
#     # List of entities to add (entity type, entity text)
#     [("FFM", "Charmm36")],
#     # List of entities to remove (entity type, entity text, occurrence index)
#     # The occurrence index is used to specify which instance of the entity to remove
#     # if there are multiple occurrences. If None, all occurrences will be removed.
#     [("FFM", "Charmm36+OPC", 0), ("MOL", "water", None)],
# )
# ```

# %%
# EXAMPLE
correct_and_visualize(
    # Path to the annotation file to correct
    "../../annotations/v3/zenodo_2537734.json",
    [("SOFTNAME", "CHARMM")],
    None,
)
# Out:
# ================================================================================
# VISUALIZATION OF ENTITIES (zenodo_2537734.json: https://zenodo.org/records/2537734)
# ================================================================================
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cellulose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOL</span>
# </mark>
#  test MD dataset for analysis with Galaxy and BRIDGE<br>This coordinate and trajectory dataset is that of cellulase and
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     octaose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOL</span>
# </mark>
#  substrate in water. It has been derived from the
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7CEL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOL</span>
# </mark>
#  PDB structure of a
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fungal cellobiohydrolase
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOL</span>
# </mark>
# .<br><br>The original enzyme has been modified to revert the mutation at position 217 and to include disulfide bonds. The
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     octaose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOL</span>
# </mark>
#  substrate is an
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     oligosaccharide
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOL</span>
# </mark>
#  consisting of 8 beta 1-4 linked
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     glucose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOL</span>
# </mark>
#  monomers.  The enzyme and substrate have been placed in a cubic
# <mark class="entity" style="background: #cdb4db; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TIP3P
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FFM</span>
# </mark>
#  water box containing 0.15 M ions (
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NaCl
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOL</span>
# </mark>
# ).<br><br>The files includes are: <br>cbh1test.pdb: the coordinates of the entire system(water, protein and substrate) in PDB format. <br>cbh1test.dcd: a short MD trajectory (16 frames) in
# <mark class="entity" style="background: #ffffba; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CHARMM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SOFTNAME</span>
# </mark>
#  DCD format.</div></span>
