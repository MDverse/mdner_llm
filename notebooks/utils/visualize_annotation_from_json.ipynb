# %% [markdown]
# # **Visualize an annotation from JSON file 🔎**
#
# ### 🎯 Objectives:
# - Load a structured JSON annotation of molecular dynamics description with entities like MOLECULE (`MOL`), FORCEFIELD (`FFM`), SIMULATION_TIME (`STIME`), TEMPERATURE (`TEMP`), SOFTWARE NAME (`SOFTNAME`) and SOFTWARE VERSION (`SOFTVERS`).
# - Visualize the annotation results for clarity and verification.

# %% [markdown]
# ## Load libraries

# %%
# %load_ext autoreload
# %autoreload 2

import json
from pathlib import Path

from mdner_llm.utils.visualize_annotations import visualize_annotations_from_json_file
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext watermark
# %watermark
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Last updated: 2026-03-02T15:13:25.998350+01:00
#
# Python implementation: CPython
# Python version       : 3.13.0
# IPython version      : 8.13.2
#
# Compiler    : Clang 18.1.8
# OS          : Linux
# Release     : 6.17.0-14-generic
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 32
# Architecture: 64bit

# %% [markdown]
# ## Step 1: Load annotation file

# %%
# Define the path to the annotation file
ANNOTATION_PATH = Path("../../annotations/v3/zenodo_259443.json")

# %%
# Load json data from the annotation file
with ANNOTATION_PATH.open(encoding="utf-8") as file:
    data = json.load(file)

text = data.get("raw_text", "")
entities = data.get("entities", [])
print(f"Path: {ANNOTATION_PATH}")
print(f"Number of entities: {len(entities)}")
print("Text:")
print(text)
# Out:
# Path: ../../annotations/v3/zenodo_259443.json
# Number of entities: 34
# Text:
# Simulations of Na+ and Ca2+ binding to phospholipid membranes
#
# Simulations of various bilayers together with ions. A DOPC bilayer in the liquid disordered phase (310 K) and a DPPC bilayer in the gel phase (293 K), both formed of 200 lipids, were simulated with the presence of either 130 mM of NaCl or 450 mM of CaCl_2. The Slipids model [1–3] is employed for lipids, tip3p model for water, the ion parameters by Smith and Dang for NaCl [4] and the ion parameters by Kohagen et al. for CaCl_2 [5]. Trajectories with NaCl are 200 ns long, while with CaCl_2 they were either 500 ns (DOPC) or 800 ns (DPPC) long.
# ...

# %% [markdown]
# ## Step 2: Visualize the annotation results

# %%
visualize_annotations_from_json_file(ANNOTATION_PATH)
# Out:
# ...
# VISUALIZATION OF ENTITIES (zenodo_259443.json)
# ...
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Simulations of
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Na+
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOL</span>
# </mark>
#  and
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ca2+
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOL</span>
# </mark>
#  binding to
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     phospholipid
# ...
