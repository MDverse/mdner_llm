# %% [markdown]
# # **Plot NER Extraction Performance — Publication Figures 📄**

# %% [markdown]
# ## **Load libraries and setup**

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
from plotly.colors import sample_colorscale

# %%
# %load_ext watermark
# %watermark
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Last updated: 2026-07-27T22:39:39.231080+02:00
#
# Python implementation: CPython
# Python version       : 3.13.13
# IPython version      : 8.13.2
#
# Compiler    : Clang 22.1.3
# OS          : Darwin
# Release     : 25.5.0
# Machine     : arm64
# Processor   : arm
# CPU cores   : 15
# Architecture: 64bit

# %%
BLUE_PURPLE_SCALE = ["#4C6EF5", "#7048E8", "#B873C9"]


def generate_palette(color_count: int) -> list[str]:
    """Sample a blue-to-purple color scale for the requested number of colors.

    Returns
    -------
    list[str]
        A list of hex color codes sampled from the blue-to-purple color scale.
    """
    sample_points = [index / max(color_count - 1, 1) for index in range(color_count)]
    return sample_colorscale(BLUE_PURPLE_SCALE, sample_points)


def apply_journal_theme(figure: go.Figure, y_axis_title: str) -> None:
    """Apply a clean, publication-ready layout to a Plotly figure."""
    figure.update_layout(
        template="simple_white",
        font={"family": "Arial, Helvetica, sans-serif", "size": 16, "color": "black"},
        plot_bgcolor="white",
        paper_bgcolor="white",
        margin={"l": 70, "r": 30, "t": 70, "b": 90},
    )
    figure.update_yaxes(
        title=y_axis_title.capitalize().replace("_", " "),
        range=[0, 1],
        tickfont={"size": 14},
        title_font={"size": 17},
        showgrid=True,
        gridcolor="rgba(0,0,0,0.08)",
        zeroline=False,
        ticks="outside",
    )
    figure.update_xaxes(
        tickfont={"size": 16},
        showgrid=False,
        tickangle=0,
        ticks="outside",
    )

# %% [markdown]
# ## **Load data**

# %%
CSV_PATH = "../results/llms/evaluation/eval_all_models.csv"  # path to your aggregated results file

df = pd.read_csv(CSV_PATH)
df
# Out:
#                                            model_name framework_name category  \
# 0                            deepseek/deepseek-v4-pro    noframework      FFM
# 1                            deepseek/deepseek-v4-pro    noframework      MOL
# 2                            deepseek/deepseek-v4-pro    noframework    STEMP
# 3                            deepseek/deepseek-v4-pro    noframework    STIME
# 4                            deepseek/deepseek-v4-pro    noframework  OVERALL
# 5                               google/gemma-4-31b-it    noframework      FFM
# 6                               google/gemma-4-31b-it    noframework      MOL
# 7                               google/gemma-4-31b-it    noframework    STEMP
# 8                               google/gemma-4-31b-it    noframework    STIME
# 9                               google/gemma-4-31b-it    noframework  OVERALL
# 10                           deepseek/deepseek-v4-pro     instructor      FFM
# 11                           deepseek/deepseek-v4-pro     instructor      MOL
# 12                           deepseek/deepseek-v4-pro     instructor    STEMP
# 13                           deepseek/deepseek-v4-pro     instructor    STIME
# 14                           deepseek/deepseek-v4-pro     instructor  OVERALL
# 15                              google/gemma-4-31b-it     instructor      FFM
# 16                              google/gemma-4-31b-it     instructor      MOL
# 17                              google/gemma-4-31b-it     instructor    STEMP
# 18                              google/gemma-4-31b-it     instructor    STIME
# 19                              google/gemma-4-31b-it     instructor  OVERALL
# 20                           deepseek/deepseek-v4-pro     instructor      FFM
# 21                           deepseek/deepseek-v4-pro     instructor      MOL
# 22                           deepseek/deepseek-v4-pro     instructor    STEMP
# 23                           deepseek/deepseek-v4-pro     instructor    STIME
# 24                           deepseek/deepseek-v4-pro     instructor  OVERALL
# 25                              google/gemma-4-31b-it     instructor      FFM
# 26                              google/gemma-4-31b-it     instructor      MOL
# 27                              google/gemma-4-31b-it     instructor    STEMP
# 28                              google/gemma-4-31b-it     instructor    STIME
# 29                              google/gemma-4-31b-it     instructor  OVERALL
# 30                              google/gemma-4-31b-it     instructor      FFM
# 31                              google/gemma-4-31b-it     instructor      MOL
# 32                              google/gemma-4-31b-it     instructor    STEMP
# 33                              google/gemma-4-31b-it     instructor    STIME
# 34                              google/gemma-4-31b-it     instructor  OVERALL
# 35  consensus_deepseek_deepseek-v4-pro_google_gemm...     instructor      FFM
# 36  consensus_deepseek_deepseek-v4-pro_google_gemm...     instructor      MOL
# 37  consensus_deepseek_deepseek-v4-pro_google_gemm...     instructor    STEMP
# 38  consensus_deepseek_deepseek-v4-pro_google_gemm...     instructor    STIME
# 39  consensus_deepseek_deepseek-v4-pro_google_gemm...     instructor  OVERALL
# 40  consensus_deepseek_deepseek-v4-pro_google_gemm...     instructor      FFM
# 41  consensus_deepseek_deepseek-v4-pro_google_gemm...     instructor      MOL
# 42  consensus_deepseek_deepseek-v4-pro_google_gemm...     instructor    STEMP
# 43  consensus_deepseek_deepseek-v4-pro_google_gemm...     instructor    STIME
# 44  consensus_deepseek_deepseek-v4-pro_google_gemm...     instructor  OVERALL
#
#     nb_texts_with_category  nb_groundtruth_entities  nb_predicted_entities  \
# 0                        1                        2                      2
# 1                        3                       19                     21
# 2                        1                        1                      1
# 3                        1                        2                      2
# 4                        3                       24                     26
# 5                        1                        2                      2
# 6                        3                       19                     17
# 7                        1                        1                      1
# 8                        1                        2                      2
# 9                        3                       24                     22
# 10                       1                        2                      2
# 11                       3                       19                     21
# 12                       1                        1                      1
# 13                       1                        2                      2
# 14                       3                       24                     26
# 15                       1                        2                      2
# 16                       3                       19                     17
# 17                       1                        1                      1
# 18                       1                        2                      2
# 19                       3                       24                     22
# 20                       1                        2                      2
# 21                       3                       19                     17
# 22                       1                        1                      1
# 23                       1                        2                      2
# 24                       3                       24                     22
# 25                       1                        2                      2
# 26                       3                       19                     18
# 27                       1                        1                      1
# 28                       1                        2                      2
# 29                       3                       24                     23
# 30                       1                        2                      2
# 31                       3                       19                     18
# 32                       1                        1                      1
# 33                       1                        2                      2
# 34                       3                       24                     23
# 35                       1                        2                      2
# 36                       3                       19                     19
# 37                       1                        1                      1
# 38                       1                        2                      2
# 39                       3                       24                     24
# 40                       1                        2                      2
# 41                       3                       19                     16
# 42                       1                        1                      1
# 43                       1                        2                      2
# 44                       3                       24                     21
#
#     nb_hallucinated_entities  pct_correct_format  true_positives  \
# 0                          0               100.0               2
# 1                          0               100.0              14
# 2                          0               100.0               1
# 3                          0               100.0               2
# 4                          0               100.0              19
# 5                          0               100.0               2
# 6                          0               100.0              14
# 7                          0               100.0               1
# 8                          0               100.0               2
# 9                          0               100.0              19
# 10                         0               100.0               2
# 11                         0               100.0              12
# 12                         0               100.0               1
# 13                         0               100.0               2
# 14                         0               100.0              17
# 15                         0               100.0               2
# 16                         0               100.0              12
# 17                         0               100.0               1
# 18                         0               100.0               2
# 19                         0               100.0              17
# 20                         0               100.0               1
# 21                         0               100.0              13
# 22                         0               100.0               1
# 23                         0               100.0               2
# 24                         0               100.0              17
# 25                         0               100.0               2
# 26                         0               100.0              15
# 27                         0               100.0               1
# 28                         0               100.0               2
# 29                         0               100.0              20
# 30                         0               100.0               2
# 31                         1               100.0              15
# 32                         0               100.0               1
# 33                         0               100.0               2
# 34                         3               100.0              20
# 35                         0               100.0               2
# 36                         0               100.0              13
# 37                         0               100.0               1
# 38                         0               100.0               2
# 39                         0               100.0              18
# 40                         0               100.0               2
# 41                         0               100.0              13
# 42                         0               100.0               1
# 43                         0               100.0               2
# 44                         0               100.0              18
#
#     false_positives  ...  precision_score  precision_score_no_hallucination  \
# 0                 0  ...         1.000000                          1.000000
# 1                 7  ...         0.666667                          0.666667
# 2                 0  ...         1.000000                          1.000000
# 3                 0  ...         1.000000                          1.000000
# 4                 7  ...         0.730769                          0.730769
# 5                 0  ...         1.000000                          1.000000
# 6                 3  ...         0.823529                          0.823529
# 7                 0  ...         1.000000                          1.000000
# 8                 0  ...         1.000000                          1.000000
# 9                 3  ...         0.863636                          0.863636
# 10                0  ...         1.000000                          1.000000
# 11                9  ...         0.571429                          0.571429
# 12                0  ...         1.000000                          1.000000
# 13                0  ...         1.000000                          1.000000
# 14                9  ...         0.653846                          0.653846
# 15                0  ...         1.000000                          1.000000
# 16                5  ...         0.705882                          0.705882
# 17                0  ...         1.000000                          1.000000
# 18                0  ...         1.000000                          1.000000
# 19                5  ...         0.772727                          0.772727
# 20                1  ...         0.500000                          0.500000
# 21                4  ...         0.764706                          0.764706
# 22                0  ...         1.000000                          1.000000
# 23                0  ...         1.000000                          1.000000
# 24                5  ...         0.772727                          0.772727
# 25                0  ...         1.000000                          1.000000
# 26                3  ...         0.833333                          0.833333
# 27                0  ...         1.000000                          1.000000
# 28                0  ...         1.000000                          1.000000
# 29                3  ...         0.869565                          0.869565
# 30                0  ...         1.000000                          1.000000
# 31                3  ...         0.833333                          0.882353
# 32                0  ...         1.000000                          1.000000
# 33                0  ...         1.000000                          1.000000
# 34                3  ...         0.869565                          0.909091
# 35                0  ...         1.000000                          1.000000
# 36                6  ...         0.684211                          0.684211
# 37                0  ...         1.000000                          1.000000
# 38                0  ...         1.000000                          1.000000
# 39                6  ...         0.750000                          0.750000
# 40                0  ...         1.000000                          1.000000
# 41                3  ...         0.812500                          0.812500
# 42                0  ...         1.000000                          1.000000
# 43                0  ...         1.000000                          1.000000
# 44                3  ...         0.857143                          0.857143
#
#     recall_score  f1_score  f1_score_no_hallucination  fbeta_0.5_score  \
# 0       1.000000  1.000000                   1.000000         1.000000
# 1       0.736842  0.700000                   0.700000         0.679612
# 2       1.000000  1.000000                   1.000000         1.000000
# 3       1.000000  1.000000                   1.000000         1.000000
# 4       0.791667  0.760000                   0.760000         0.742187
# 5       1.000000  1.000000                   1.000000         1.000000
# 6       0.736842  0.777778                   0.777778         0.804598
# 7       1.000000  1.000000                   1.000000         1.000000
# 8       1.000000  1.000000                   1.000000         1.000000
# 9       0.791667  0.826087                   0.826087         0.848214
# 10      1.000000  1.000000                   1.000000         1.000000
# 11      0.631579  0.600000                   0.600000         0.582524
# 12      1.000000  1.000000                   1.000000         1.000000
# 13      1.000000  1.000000                   1.000000         1.000000
# 14      0.708333  0.680000                   0.680000         0.664062
# 15      1.000000  1.000000                   1.000000         1.000000
# 16      0.631579  0.666667                   0.666667         0.689655
# 17      1.000000  1.000000                   1.000000         1.000000
# 18      1.000000  1.000000                   1.000000         1.000000
# 19      0.708333  0.739130                   0.739130         0.758929
# 20      0.500000  0.500000                   0.500000         0.500000
# 21      0.684211  0.722222                   0.722222         0.747126
# 22      1.000000  1.000000                   1.000000         1.000000
# 23      1.000000  1.000000                   1.000000         1.000000
# 24      0.708333  0.739130                   0.739130         0.758929
# 25      1.000000  1.000000                   1.000000         1.000000
# 26      0.789474  0.810811                   0.810811         0.824176
# 27      1.000000  1.000000                   1.000000         1.000000
# 28      1.000000  1.000000                   1.000000         1.000000
# 29      0.833333  0.851064                   0.851064         0.862069
# 30      1.000000  1.000000                   1.000000         1.000000
# 31      0.789474  0.810811                   0.833333         0.824176
# 32      1.000000  1.000000                   1.000000         1.000000
# 33      1.000000  1.000000                   1.000000         1.000000
# 34      0.833333  0.851064                   0.869565         0.862069
# 35      1.000000  1.000000                   1.000000         1.000000
# 36      0.684211  0.684211                   0.684211         0.684211
# 37      1.000000  1.000000                   1.000000         1.000000
# 38      1.000000  1.000000                   1.000000         1.000000
# 39      0.750000  0.750000                   0.750000         0.750000
# 40      1.000000  1.000000                   1.000000         1.000000
# 41      0.684211  0.742857                   0.742857         0.783133
# 42      1.000000  1.000000                   1.000000         1.000000
# 43      1.000000  1.000000                   1.000000         1.000000
# 44      0.750000  0.800000                   0.800000         0.833333
#
#     fbeta_0.5_score_no_hallucination              scenario  \
# 0                           1.000000  benchmark_strategies
# 1                           0.679612  benchmark_strategies
# 2                           1.000000  benchmark_strategies
# 3                           1.000000  benchmark_strategies
# 4                           0.742187  benchmark_strategies
# 5                           1.000000  benchmark_strategies
# 6                           0.804598  benchmark_strategies
# 7                           1.000000  benchmark_strategies
# 8                           1.000000  benchmark_strategies
# 9                           0.848214  benchmark_strategies
# 10                          1.000000  benchmark_strategies
# 11                          0.582524  benchmark_strategies
# 12                          1.000000  benchmark_strategies
# 13                          1.000000  benchmark_strategies
# 14                          0.664062  benchmark_strategies
# 15                          1.000000  benchmark_strategies
# 16                          0.689655  benchmark_strategies
# 17                          1.000000  benchmark_strategies
# 18                          1.000000  benchmark_strategies
# 19                          0.758929  benchmark_strategies
# 20                          0.500000  benchmark_strategies
# 21                          0.747126  benchmark_strategies
# 22                          1.000000  benchmark_strategies
# 23                          1.000000  benchmark_strategies
# 24                          0.758929  benchmark_strategies
# 25                          1.000000  benchmark_strategies
# 26                          0.824176  benchmark_strategies
# 27                          1.000000  benchmark_strategies
# 28                          1.000000  benchmark_strategies
# 29                          0.862069  benchmark_strategies
# 30                          1.000000      benchmark_models
# 31                          0.862069      benchmark_models
# 32                          1.000000      benchmark_models
# 33                          1.000000      benchmark_models
# 34                          0.892857      benchmark_models
# 35                          1.000000            evaluation
# 36                          0.684211            evaluation
# 37                          1.000000            evaluation
# 38                          1.000000            evaluation
# 39                          0.750000            evaluation
# 40                          1.000000            evaluation
# 41                          0.783133            evaluation
# 42                          1.000000            evaluation
# 43                          1.000000            evaluation
# 44                          0.833333            evaluation
#
#                               combo                model_safe
# 0       no_instructor_no_guidelines  deepseek_deepseek-v4-pro
# 1       no_instructor_no_guidelines  deepseek_deepseek-v4-pro
# 2       no_instructor_no_guidelines  deepseek_deepseek-v4-pro
# 3       no_instructor_no_guidelines  deepseek_deepseek-v4-pro
# 4       no_instructor_no_guidelines  deepseek_deepseek-v4-pro
# 5       no_instructor_no_guidelines     google_gemma-4-31b-it
# 6       no_instructor_no_guidelines     google_gemma-4-31b-it
# 7       no_instructor_no_guidelines     google_gemma-4-31b-it
# 8       no_instructor_no_guidelines     google_gemma-4-31b-it
# 9       no_instructor_no_guidelines     google_gemma-4-31b-it
# 10    with_instructor_no_guidelines  deepseek_deepseek-v4-pro
# 11    with_instructor_no_guidelines  deepseek_deepseek-v4-pro
# 12    with_instructor_no_guidelines  deepseek_deepseek-v4-pro
# 13    with_instructor_no_guidelines  deepseek_deepseek-v4-pro
# 14    with_instructor_no_guidelines  deepseek_deepseek-v4-pro
# 15    with_instructor_no_guidelines     google_gemma-4-31b-it
# 16    with_instructor_no_guidelines     google_gemma-4-31b-it
# 17    with_instructor_no_guidelines     google_gemma-4-31b-it
# 18    with_instructor_no_guidelines     google_gemma-4-31b-it
# 19    with_instructor_no_guidelines     google_gemma-4-31b-it
# 20  with_instructor_with_guidelines  deepseek_deepseek-v4-pro
# 21  with_instructor_with_guidelines  deepseek_deepseek-v4-pro
# 22  with_instructor_with_guidelines  deepseek_deepseek-v4-pro
# 23  with_instructor_with_guidelines  deepseek_deepseek-v4-pro
# 24  with_instructor_with_guidelines  deepseek_deepseek-v4-pro
# 25  with_instructor_with_guidelines     google_gemma-4-31b-it
# 26  with_instructor_with_guidelines     google_gemma-4-31b-it
# 27  with_instructor_with_guidelines     google_gemma-4-31b-it
# 28  with_instructor_with_guidelines     google_gemma-4-31b-it
# 29  with_instructor_with_guidelines     google_gemma-4-31b-it
# 30            instructor_guidelines     google_gemma-4-31b-it
# 31            instructor_guidelines     google_gemma-4-31b-it
# 32            instructor_guidelines     google_gemma-4-31b-it
# 33            instructor_guidelines     google_gemma-4-31b-it
# 34            instructor_guidelines     google_gemma-4-31b-it
# 35                        consensus                    temp_1
# 36                        consensus                    temp_1
# 37                        consensus                    temp_1
# 38                        consensus                    temp_1
# 39                        consensus                    temp_1
# 40                        consensus              temp_1_and_2
# 41                        consensus              temp_1_and_2
# 42                        consensus              temp_1_and_2
# 43                        consensus              temp_1_and_2
# 44                        consensus              temp_1_and_2
#
# [45 rows x 28 columns]

# %%
# Filter with only the overall results for each model
overall = df[df["category"] == "OVERALL"]  # or OVERALL_MICRO / OVERALL_MACRO
overall
# Out:
#                                            model_name framework_name category  \
# 4                            deepseek/deepseek-v4-pro    noframework  OVERALL
# 9                               google/gemma-4-31b-it    noframework  OVERALL
# 14                           deepseek/deepseek-v4-pro     instructor  OVERALL
# 19                              google/gemma-4-31b-it     instructor  OVERALL
# 24                           deepseek/deepseek-v4-pro     instructor  OVERALL
# 29                              google/gemma-4-31b-it     instructor  OVERALL
# 34                              google/gemma-4-31b-it     instructor  OVERALL
# 39  consensus_deepseek_deepseek-v4-pro_google_gemm...     instructor  OVERALL
# 44  consensus_deepseek_deepseek-v4-pro_google_gemm...     instructor  OVERALL
#
#     nb_texts_with_category  nb_groundtruth_entities  nb_predicted_entities  \
# 4                        3                       24                     26
# 9                        3                       24                     22
# 14                       3                       24                     26
# 19                       3                       24                     22
# 24                       3                       24                     22
# 29                       3                       24                     23
# 34                       3                       24                     23
# 39                       3                       24                     24
# 44                       3                       24                     21
#
#     nb_hallucinated_entities  pct_correct_format  true_positives  \
# 4                          0               100.0              19
# 9                          0               100.0              19
# 14                         0               100.0              17
# 19                         0               100.0              17
# 24                         0               100.0              17
# 29                         0               100.0              20
# 34                         3               100.0              20
# 39                         0               100.0              18
# 44                         0               100.0              18
#
#     false_positives  ...  precision_score  precision_score_no_hallucination  \
# 4                 7  ...         0.730769                          0.730769
# 9                 3  ...         0.863636                          0.863636
# 14                9  ...         0.653846                          0.653846
# 19                5  ...         0.772727                          0.772727
# 24                5  ...         0.772727                          0.772727
# 29                3  ...         0.869565                          0.869565
# 34                3  ...         0.869565                          0.909091
# 39                6  ...         0.750000                          0.750000
# 44                3  ...         0.857143                          0.857143
#
#     recall_score  f1_score  f1_score_no_hallucination  fbeta_0.5_score  \
# 4       0.791667  0.760000                   0.760000         0.742187
# 9       0.791667  0.826087                   0.826087         0.848214
# 14      0.708333  0.680000                   0.680000         0.664062
# 19      0.708333  0.739130                   0.739130         0.758929
# 24      0.708333  0.739130                   0.739130         0.758929
# 29      0.833333  0.851064                   0.851064         0.862069
# 34      0.833333  0.851064                   0.869565         0.862069
# 39      0.750000  0.750000                   0.750000         0.750000
# 44      0.750000  0.800000                   0.800000         0.833333
#
#     fbeta_0.5_score_no_hallucination              scenario  \
# 4                           0.742187  benchmark_strategies
# 9                           0.848214  benchmark_strategies
# 14                          0.664062  benchmark_strategies
# 19                          0.758929  benchmark_strategies
# 24                          0.758929  benchmark_strategies
# 29                          0.862069  benchmark_strategies
# 34                          0.892857      benchmark_models
# 39                          0.750000            evaluation
# 44                          0.833333            evaluation
#
#                               combo                model_safe
# 4       no_instructor_no_guidelines  deepseek_deepseek-v4-pro
# 9       no_instructor_no_guidelines     google_gemma-4-31b-it
# 14    with_instructor_no_guidelines  deepseek_deepseek-v4-pro
# 19    with_instructor_no_guidelines     google_gemma-4-31b-it
# 24  with_instructor_with_guidelines  deepseek_deepseek-v4-pro
# 29  with_instructor_with_guidelines     google_gemma-4-31b-it
# 34            instructor_guidelines     google_gemma-4-31b-it
# 39                        consensus                    temp_1
# 44                        consensus              temp_1_and_2
#
# [9 rows x 28 columns]

# %% [markdown]
# ## **Figure 1 — Effect of Prompt Strategy per Model**

# %%
# set manually from your annotation agreement study
HUMAN_IAA = 0.89

# Set the metric to plot: f1_score, precision, or recall
METRIC = "f1_score"

# %%
def build_strategy_figure(
    overall: pd.DataFrame, human_iaa: float, metric: str
) -> go.Figure:
    """Build the prompt-strategy comparison figure.

    Returns
    -------
    go.Figure
        A Plotly figure comparing performance of different models
        across prompt strategies.
    """
    data = overall[overall["scenario"] == "benchmark_strategies"]
    combo_labels = {
        "no_instructor_no_guidelines": "No instructor no guideline",
        "with_instructor_no_guidelines": "With instructor no guideline",
        "with_instructor_with_guidelines": "With instructor with guideline",
        "with_instructor_with_guidelines_normalization": (
            "With instructor with guideline and normalization"
        ),
    }
    available_combos = set(data["combo"].unique())
    combo_order = [c for c in combo_labels if c in available_combos]

    models = data["model_safe"].unique()
    palette = generate_palette(len(models))

    figure = go.Figure()
    for model, color in zip(models, palette, strict=False):
        subset = (
            data[data["model_safe"] == model].set_index("combo").reindex(combo_order)
        )
        figure.add_bar(
            x=[combo_labels[combo] for combo in combo_order],
            y=subset[metric],
            name=model,
            marker={"color": color, "line": {"color": "white", "width": 1}},
            text=subset[metric].round(2),
            textposition="outside",
            textfont={"size": 13},
        )

    figure.add_hline(
        y=human_iaa,
        line={"color": "#555555", "dash": "dash", "width": 1.5},
        annotation_text="Human IAA",
        annotation_position="top left",
        annotation_font={"size": 14, "color": "#555555"},
    )

    apply_journal_theme(figure, metric)
    figure.update_layout(
        hovermode=False,
        bargroupgap=0.08,
        legend={
            "orientation": "h",
            "yanchor": "bottom",
            "y": 1.02,
            "xanchor": "center",
            "x": 0.5,
            "font": {"size": 15},
        },
    )
    return figure


strategy_figure = build_strategy_figure(overall, HUMAN_IAA, METRIC)
strategy_figure.show()

# %% [markdown]
# ## Figure 2 — Standalone Models vs. Consensus

# %%
# Set the sta
standalone_models = [
    "deepseek/deepseek-v4-pro",
    "google/gemma-4-31b-it",
    "openai/gpt-oss-120b",
    "qwen/qwen3.7-max"
]

# Set the metric to plot: f1_score, precision, or recall
METRIC = "f1_score"

# %%
def build_consensus_figure(
    overall: pd.DataFrame, standalone_models: list[str], metric: str
) -> go.Figure:
    """Build the standalone-models-vs-consensus figure.

    Returns
    -------
    go.Figure
        A Plotly figure comparing performance of standalone models
        against consensus models at different temperatures.
    """
    # Get the relevant data for standalone models
    solo = overall[
        (overall["scenario"] == "benchmark_models")
        & (overall["combo"] == "instructor_guidelines")
        & (overall["model_name"].isin(standalone_models))
    ]
    # Get the relevant data for consensus models
    cons = overall[
        (overall["scenario"] == "evaluation") & (overall["combo"] == "consensus")
    ].set_index("model_safe")
    # Plot the data
    labels = [*solo["model_name"], "Consensus<br>(T=1)", "Consensus<br>(T=1, 2)"]
    scores = [
        *solo[metric],
        cons.loc["temp_1", metric],
        cons.loc["temp_1_and_2", metric],
    ]
    figure = go.Figure(
        go.Bar(
            x=labels,
            y=scores,
            marker_color=generate_palette(len(labels)),
            marker_line={"color": "white", "width": 1},
            text=[f"{s:.2f}" for s in scores],
            textposition="outside",
            textfont_size=13,
        )
    )
    apply_journal_theme(figure, metric)
    figure.update_layout(hovermode=False, showlegend=False, bargap=0.3)
    return figure


consensus_figure = build_consensus_figure(overall, standalone_models, METRIC)
consensus_figure.show()
