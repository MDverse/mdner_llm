# %% [markdown]
# # Correct and visualize new annotations 🛠️

# %% [markdown]
# ## Load libraries

# %%
from pathlib import Path

from mdner_llm.utils.visualize_annotations import visualize_annotations
from mdner_llm.utils.correct_annotations import correct_and_visualize

# %%
# %load_ext watermark
# %watermark
# %watermark --packages json,pandas,spacy
# Out:
# Last updated: 2026-02-26T11:33:46.075516+01:00
#
# Python implementation: CPython
# Python version       : 3.13.0
# IPython version      : 8.13.2
#
# Compiler    : Clang 18.1.8
# OS          : Linux
# Release     : 6.17.0-14-generic
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 32
# Architecture: 64bit
#
# json  : 2.0.9
# pandas: 2.2.3
# spacy : 3.8.11

# %% [markdown]
# ## Load annotations

# %%
# First load text file with the file paths of the annotations to correct
annotation_files = Path("../results/50_selected_files_20260226_102820.txt").read_text()
annotation_files = annotation_files.splitlines()
# Reformat file paths to be relative to the current working directory
annotation_files = [Path(f"../{path}") for path in annotation_files]
print(f"Number of annotation files to correct: {len(annotation_files)}")
print(f"First 3 annotation files:\n{[str(p) for p in annotation_files[:3]]}")
# Out:
# Number of annotation files to correct: 50
# First 3 annotation files:
# ['../annotations/v3/zenodo_3248612.json', '../annotations/v3/zenodo_838635.json', '../annotations/v3/zenodo_14594.json']

# %% [markdown]
# ## Display annotations

# %%
for annotation_file_path in annotation_files:
    # Visualize annotation with spacy's displacy
    visualize_annotations(annotation_file_path)
# Out:
# ...
# VISUALIZATION OF ENTITIES (zenodo_3248612.json)
# ...
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Simulation
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CER160
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOL</span>
# </mark>
# _128_
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     POPC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOL</span>
# </mark>
# _512_
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NaCl
# ...

# %% [markdown]
# ## Correct annotations

# %%
correct_and_visualize(
    Path("../annotations/v3/zenodo_3248612.json"),
    [("FFMNAME", "charmm36")],
    [("FFM", "charmm36")]
)
# Out:
# ...
# VISUALIZATION OF ENTITIES (zenodo_3248612.json)
# ...
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Simulation
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CER160
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOL</span>
# </mark>
# _128_
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     POPC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOL</span>
# </mark>
# _512_
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NaCl
# ...

# %%
correct_and_visualize(
    Path("../annotations/v3/zenodo_838635.json"),
    [("FFMNAME", "Charmm36"), ("FFMNAME", "OPC"), ("FFMNAME", "water model")],
    [("FFM", "Charmm36"), ("FFM", "OPC"), ("FFM", "Charmm36+OPC"), ("MOL", "water")]
)
# Out:
# ...
# VISUALIZATION OF ENTITIES (zenodo_838635.json)
# ...
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Large
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DPPC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOL</span>
# </mark>
#  monolayer simulations with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Charmm36
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FFMNAME</span>
# </mark>
# +
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OPC
# ...

# %%
correct_and_visualize(
    Path("../annotations/v3/zenodo_14594.json"),
    [("FFMNAME", "GROMOS"), ("FFMVERS", "53A6_L")],
    None
)
# Out:
# ...
# VISUALIZATION OF ENTITIES (zenodo_14594.json)
# ...
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">MD simulation trajectory and related files for
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DPPC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOL</span>
# </mark>
#  bilayer in full hydration (Poger
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GROMOS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FFMNAME</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     53A6_L
# ...

# %%
correct_and_visualize(
    Path("../annotations/v3/zenodo_6755131.json"),
    [("FFMNAME", "TIP3P"), ("FFMNAME", "GAFF")],
    [("FFM", "TIP3P"), ("FFM", "GAFF")]
)
# Out:
# ...
# VISUALIZATION OF ENTITIES (zenodo_6755131.json)
# ...
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">All-atom molecular dynamics simulations of
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     phenylalanine-4-hydroxylase
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOL</span>
# </mark>
#  (
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PAH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOL</span>
# </mark>
# ) tetramer to investigate the impact of two novel heterozygous mutations, p.Y198N and p.Y204F, observed in a classical phenylketonuria patient
# ...

# %%
correct_and_visualize(
    Path("../annotations/v3/zenodo_15550.json"),
    [("FFMNAME", "GAFFlipid")],
    [("FFM", "GAFFlipid")]
)
# Out:
# ...
# VISUALIZATION OF ENTITIES (zenodo_15550.json)
# ...
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">MD simulation trajectory and related files for
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DPPC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOL</span>
# </mark>
#  bilayer (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GAFFlipid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FFMNAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #ffffba; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gromacs
# ...

# %%
correct_and_visualize(
    Path("../annotations/v3/zenodo_13853.json"),
    [("FFMNAME", "GAFFlipid")],
    [("FFM", "GAFFlipid")]
)
# Out:
# ...
# VISUALIZATION OF ENTITIES (zenodo_13853.json)
# ...
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">MD simulation trajectory and related files for
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     POPC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOL</span>
# </mark>
#  bilayer in low hydration (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GAFFlipid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FFMNAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #ffffba; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gromacs
# ...

# %%
correct_and_visualize(
    Path("../annotations/v3/zenodo_4300706.json"),
    [("FFMNAME", "Charmm36"), ("FFMVERS", "v. June 2015")],
    [("FFM", "Charmm36 (v. June 2015)")]
)
# Out:
# ...
# VISUALIZATION OF ENTITIES (zenodo_4300706.json)
# ...
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">256
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DPPC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOL</span>
# </mark>
#  Molecules bilayer in pure
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Water
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOL</span>
# </mark>
# , simulated at
# <mark class="entity" style="background: #ffb3ba; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     288K
# ...

# %%
correct_and_visualize(
    Path("../annotations/v3/zenodo_1118682.json"),
    [("FFMNAME", "ECC-POPC"), ("FFMNAME", "SPC/E")],
    [("FFM", "ECC-POPC"), ("FFM", "SPC/E")]
)
# Out:
# ...
# VISUALIZATION OF ENTITIES (zenodo_1118682.json)
# ...
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Simulations of
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     POPC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOL</span>
# </mark>
#  lipid bilayer in
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     water
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOL</span>
# </mark>
#  solution with various molar fractions of cationic surfactant
# <mark class="entity" style="background: #bae1ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
# ...
